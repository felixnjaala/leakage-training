# %%
import pandas as pd
import numpy as np

# %% [markdown]
# DATA STRUCTURES IN PANDAS

# %%
#SERIES
series=pd.Series([10,20,30],index=['a','b','c'])
series
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
#dataframe
dat={
    'name':['alice','sam','bob'],
    'age':[30,24,21],
    'salary':[4000,6000,70000]
}
df=pd.DataFrame(dat)
dat
# Out:
# {'name': ['alice', 'sam', 'bob'],
#  'age': [30, 24, 21],
#  'salary': [4000, 6000, 70000]}

# %%
dt = pd.read_csv("/home/fahim/FELIX/data-analysis/data/housing.csv")

# %%
dt.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
dt.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# ...

# %%
dt.shape
# Out:
# (20640, 10)

# %%
dt.index
# Out:
# RangeIndex(start=0, stop=20640, step=1)

# %%
dt.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
dt.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
dt.count()
# Out:
# longitude             20640
# latitude              20640
# housing_median_age    20640
# total_rooms           20640
# total_bedrooms        20433
# population            20640
# households            20640
# median_income         20640
# median_house_value    20640
# ocean_proximity       20640
# dtype: int64

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
dt.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
dt.nunique()
# Out:
# longitude               844
# latitude                862
# housing_median_age       52
# total_rooms            5926
# total_bedrooms         1923
# population             3888
# households             1815
# median_income         12928
# median_house_value     3842
# ocean_proximity           5
# dtype: int64

# %%
dt['median_income'].unique()
# Out:
# array([8.3252, 8.3014, 7.2574, ..., 2.3598, 2.3661, 2.0943],
#       shape=(12928,))

# %%
dt.drop(columns= "total_bedrooms" , inplace=True)

# %%
dt.population  .mean()
# Out:
# np.float64(1425.4767441860465)

# %%
dt.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  population  \
# 0    -122.23     37.88                41.0        880.0       322.0
# 1    -122.22     37.86                21.0       7099.0      2401.0
# 2    -122.24     37.85                52.0       1467.0       496.0
# 3    -122.25     37.85                52.0       1274.0       558.0
# 4    -122.25     37.85                52.0       1627.0       565.0
#
#    households  median_income  median_house_value ocean_proximity
# 0       126.0         8.3252            452600.0        NEAR BAY
# 1      1138.0         8.3014            358500.0        NEAR BAY
# 2       177.0         7.2574            352100.0        NEAR BAY
# 3       219.0         5.6431            341300.0        NEAR BAY
# 4       259.0         3.8462            342200.0        NEAR BAY

# %%
dt.population.std()
# Out:
# np.float64(1132.462121765341)

# %%
dt.population.var()
# Out:
# np.float64(1282470.457233258)

# %%
dt.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#          population    households  median_income  median_house_value
# count  20640.000000  20640.000000   20640.000000        20640.000000
# mean    1425.476744    499.539680       3.870671       206855.816909
# std     1132.462122    382.329753       1.899822       115395.615874
# min        3.000000      1.000000       0.499900        14999.000000
# ...

# %%
dt.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  population  \
# 0    -122.23     37.88                41.0        880.0       322.0
# 1    -122.22     37.86                21.0       7099.0      2401.0
# 2    -122.24     37.85                52.0       1467.0       496.0
# 3    -122.25     37.85                52.0       1274.0       558.0
# 4    -122.25     37.85                52.0       1627.0       565.0
#
#    households  median_income  median_house_value ocean_proximity
# 0       126.0         8.3252            452600.0        NEAR BAY
# 1      1138.0         8.3014            358500.0        NEAR BAY
# 2       177.0         7.2574            352100.0        NEAR BAY
# 3       219.0         5.6431            341300.0        NEAR BAY
# 4       259.0         3.8462            342200.0        NEAR BAY

# %%
dt[(dt['population'] > 41)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  population  \
# 0        -122.23     37.88                41.0        880.0       322.0
# 1        -122.22     37.86                21.0       7099.0      2401.0
# 2        -122.24     37.85                52.0       1467.0       496.0
# 3        -122.25     37.85                52.0       1274.0       558.0
# 4        -122.25     37.85                52.0       1627.0       565.0
# ...          ...       ...                 ...          ...         ...
# 20635    -121.09     39.48                25.0       1665.0       845.0
# 20636    -121.21     39.49                18.0        697.0       356.0
# 20637    -121.22     39.43                17.0       2254.0      1007.0
# 20638    -121.32     39.43                18.0       1860.0       741.0
# 20639    -121.24     39.37                16.0       2785.0      1387.0
#
#        households  median_income  median_house_value ocean_proximity
# ...

# %%
G41=dt[(dt['population'] > 200) ]

# %%
G41
# Out:
#        longitude  latitude  housing_median_age  total_rooms  population  \
# 0        -122.23     37.88                41.0        880.0       322.0
# 1        -122.22     37.86                21.0       7099.0      2401.0
# 2        -122.24     37.85                52.0       1467.0       496.0
# 3        -122.25     37.85                52.0       1274.0       558.0
# 4        -122.25     37.85                52.0       1627.0       565.0
# ...          ...       ...                 ...          ...         ...
# 20635    -121.09     39.48                25.0       1665.0       845.0
# 20636    -121.21     39.49                18.0        697.0       356.0
# 20637    -121.22     39.43                17.0       2254.0      1007.0
# 20638    -121.32     39.43                18.0       1860.0       741.0
# 20639    -121.24     39.37                16.0       2785.0      1387.0
#
#        households  median_income  median_house_value ocean_proximity
# ...

# %%
dt.sort_values('median_income', ascending=True)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  population  \
# 19523    -121.01     37.65                52.0        178.0       152.0
# 7125     -118.04     33.90                36.0         15.0        15.0
# 6343     -117.75     34.06                52.0         62.0        44.0
# 13999    -116.90     34.69                10.0        337.0       108.0
# 20091    -120.19     38.07                43.0        102.0        44.0
# ...          ...       ...                 ...          ...         ...
# 8849     -118.40     34.08                52.0       3815.0      1266.0
# 18501    -121.59     37.19                52.0        220.0        55.0
# 6399     -118.04     34.13                35.0        249.0       268.0
# 18504    -121.96     37.13                26.0         50.0        17.0
# 1566     -121.96     37.74                 2.0        200.0        25.0
#
#        households  median_income  median_house_value ocean_proximity
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   population          20640 non-null  float64
#  5   households          20640 non-null  float64
#  6   median_income       20640 non-null  float64
#  7   median_house_value  20640 non-null  float64
#  8   ocean_proximity     20640 non-null  object
# dtypes: float64(8), object(1)
# memory usage: 1.4+ MB

# %%
data = dt.select_dtypes(['object']).columns

# %%
data
# Out:
# Index(['ocean_proximity'], dtype='object')

# %%
data = dt[data].apply(lambda x: pd.factorize(x)[0])

# %%
data
# Out:
#        ocean_proximity
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 20635                2
# 20636                2
# 20637                2
# 20638                2
# 20639                2
#
# [20640 rows x 1 columns]

# %%
dt.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  population  \
# 0    -122.23     37.88                41.0        880.0       322.0
# 1    -122.22     37.86                21.0       7099.0      2401.0
# 2    -122.24     37.85                52.0       1467.0       496.0
# 3    -122.25     37.85                52.0       1274.0       558.0
# 4    -122.25     37.85                52.0       1627.0       565.0
#
#    households  median_income  median_house_value ocean_proximity
# 0       126.0         8.3252            452600.0        NEAR BAY
# 1      1138.0         8.3014            358500.0        NEAR BAY
# 2       177.0         7.2574            352100.0        NEAR BAY
# 3       219.0         5.6431            341300.0        NEAR BAY
# 4       259.0         3.8462            342200.0        NEAR BAY

# %%
dt["housing_median_age"] =dt["housing_median_age"].apply(lambda x:x+3)

# %%
dt.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  population  \
# 0    -122.23     37.88                44.0        880.0       322.0
# 1    -122.22     37.86                24.0       7099.0      2401.0
# 2    -122.24     37.85                55.0       1467.0       496.0
# 3    -122.25     37.85                55.0       1274.0       558.0
# 4    -122.25     37.85                55.0       1627.0       565.0
#
#    households  median_income  median_house_value ocean_proximity
# 0       126.0         8.3252            452600.0        NEAR BAY
# 1      1138.0         8.3014            358500.0        NEAR BAY
# 2       177.0         7.2574            352100.0        NEAR BAY
# 3       219.0         5.6431            341300.0        NEAR BAY
# 4       259.0         3.8462            342200.0        NEAR BAY

# %%
dt[~(dt['median_house_value']>452600.0)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  population  \
# 0        -122.23     37.88                44.0        880.0       322.0
# 1        -122.22     37.86                24.0       7099.0      2401.0
# 2        -122.24     37.85                55.0       1467.0       496.0
# 3        -122.25     37.85                55.0       1274.0       558.0
# 4        -122.25     37.85                55.0       1627.0       565.0
# ...          ...       ...                 ...          ...         ...
# 20635    -121.09     39.48                28.0       1665.0       845.0
# 20636    -121.21     39.49                21.0        697.0       356.0
# 20637    -121.22     39.43                20.0       2254.0      1007.0
# 20638    -121.32     39.43                21.0       1860.0       741.0
# 20639    -121.24     39.37                19.0       2785.0      1387.0
#
#        households  median_income  median_house_value ocean_proximity
# ...
